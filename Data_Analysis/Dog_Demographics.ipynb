# %% [markdown]
# [Dog_Demographics in US 2022/2023](https://financesonline.com/number-of-dogs-in-the-us/)

# %%
import matplotlib.pyplot as plt

year = [2008, 2010, 2012, 2014, 2016, 2018]
dogs = [77.5,78.2,83.3,77.8,89.7,90]
cats = [67.5,68.2,93.3,67.8,99.7,80]

plt.plot(year, dogs)     #  plot is the default and is a LINE plot
plt.plot(year, cats)
plt.legend(["dogs","cats"])
plt.show()

# %%
import matplotlib.pyplot as plt

year = [2008, 2010, 2012, 2014, 2016, 2018]
dogs = [77.5,78.2,83.3,77.8,89.7,90]

plt.barh(year, dogs)
plt.xlabel("Millions of Dogs")
plt.ylabel("Year")
plt.title("Number of Dogs in the US")
plt.show()

# %%
import matplotlib.pyplot as plt

gender = ['Male', 'Female']
dogs = [80, 68]

ax =plt.bar(gender, dogs, width=0.7, color=('blue', 'red'))
plt.xlabel("Gender")
plt.ylabel("Percent of Gender")
plt.ylim(0, 100)
plt.title("Dog Ownership by Gender")
plt.show()

# %%
import matplotlib.pyplot as plt

generation  = ['All', 'Millennials', 'Gen X', "Boomers"]    
percent = [48, 61, 52, 37]

years = ['1946-1964','1965-1980','1981-1996','1997-2012']  # Gen Z  2010-2025

plt.bar(generation, percent, width=0.7, color=('blue', 'red', 'green', 'purple'))
plt.xlabel("Generation Catagory", fontsize = 14)
plt.ylabel("Percent of Dog Ownership", fontsize = 12)
plt.ylim(0, 100)
plt.title("Dog Ownership by Generation Catagory", fontsize = 16)
plt.show()

# %%
import matplotlib.pyplot as plt

generation  = ['All', 'Millennials', 'Gen X', "Boomers"]    
percent = [48, 61, 52, 37]

years = ['1946-1964','1965-1980','1981-1996','1997-2012']  # Gen Z  2010-2025

plt.bar(generation, percent, width=0.7, color=('blue', 'red', 'green', 'purple'))
plt.xlabel("Generation Catagory", fontsize = 14)
plt.ylabel("Percent of Dog Ownership", fontsize = 12)
plt.ylim(0, 100)
plt.title("Dog Ownership by Generation Catagory", fontsize = 16)

plt.text(0,percent[0]+2, str(percent[0]) + " %", ha = 'center')
plt.text(1,percent[1]+2, str(percent[1]) + " %", ha = 'center')
plt.text(2,percent[2]+2, str(percent[2]) + " %", ha = 'center')
plt.text(3,percent[3]+2, str(percent[3]) + " %", ha = 'center')

plt.show()

# %%
import matplotlib.pyplot as plt

generation  = ['Millennials', 'Gen X', "Boomers"]    
percent = [ 61, 52, 37]

plt.title("Dog Ownership by Generation Catagory", fontsize = 16)

plt.pie(percent, labels = generation)
plt.show()
